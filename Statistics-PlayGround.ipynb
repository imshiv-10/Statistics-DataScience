# %% [markdown]
# <a href="https://colab.research.google.com/github/imshiv-10/Statistics-DataScience/blob/main/Statistics-PlayGround.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
sample_1 = np.random.choice(1000, 1000, replace=True)

# %%
len(sample_1)
# Out:
# 1000

# %%
sample_1
# Out:
# array([524, 273, 822, 966, 340, 430, 324, 735, 283, 806,   6, 628, 552,
#        919,  41, 955, 742, 620, 555, 394, 960, 578, 115, 902, 743, 531,
#        107,  54, 118, 819, 373, 493, 206, 847, 948, 184, 356, 503, 463,
#        141, 105, 776, 317, 569, 975, 259, 543, 878, 758, 173, 251, 936,
#        707, 760, 539, 766, 973, 452, 442, 941, 443, 237, 459, 255, 135,
#        946, 907, 533,  22, 408, 117, 385, 544, 395, 482, 541, 845, 648,
#        216, 190,  94,  60, 928, 187, 146, 596, 993, 759, 158, 800, 597,
#        332, 775, 965, 461, 401, 259, 616, 793, 473,  80, 322, 381, 289,
#        560, 639, 206, 638, 674, 939,  17, 925, 157, 606, 231, 910, 270,
#        544, 644, 591, 468,  98, 716, 432, 777, 821,  47, 240, 828, 322,
#        702, 775, 710, 986, 328, 902, 650, 571,  70, 644, 381, 447, 722,
#        504, 150, 126, 126, 215, 761, 390, 305, 520, 647, 869,  74, 770,
#        834, 780, 414, 158, 438, 252, 769, 972, 938, 561, 106, 583, 108,
# ...
